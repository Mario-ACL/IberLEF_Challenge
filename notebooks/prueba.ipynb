# %% [markdown]
# # Data Overview
# Mario Castro

# %%
import pandas as pd

# %%
path = r"../Data/raw"

df_info = pd.read_csv(f"{path}/INFO_AUG.csv")
df_quest = pd.read_csv(f"{path}/QUEST_AUG.csv")
df_reflex = pd.read_csv(f"{path}/REFLEX_AUG.csv")

# %% [markdown]
# ## Info dataframe:

# %%
df_info.head()
# Out:
#                                     client_utterance  \
# 0  He estado usando los ejercicios de respiración...
# 1  He estado usando los ejercicios de respiración...
# 2  He intentado dejar de fumar varias veces, pero...
# 3  He intentado dejar de fumar varias veces, pero...
# 4  Sé que fumo demasiado, pero me ayuda a relajar...
#
#                                  clinician_utterance behavior_code_1
# 0  Estudios muestran que el 65% de los veteranos ...              GI
# 1  Como ya has experimentado un avance en tu cont...              PE
# 2  La nicotina en el cuerpo se reduce a la mitad ...              GI
# 3  Tu fuerza en el servicio puede aplicarse ahora...              PE
# 4  El uso crónico de marihuana puede alterar la m...              GI

# %%
df_info.shape
# Out:
# (200, 3)

# %%
df_info['behavior_code_1'].value_counts()
# Out:
# behavior_code_1
# GI    100
# PE    100
# Name: count, dtype: int64

# %% [markdown]
# ## Quest dataframe:

# %%
df_quest.head()
# Out:
#                                     client_utterance  \
# 0  He estado practicando técnicas de respiración ...
# 1  He estado practicando técnicas de respiración ...
# 2  Hace dos semanas que dejé de fumar, y aunque a...
# 3  Hace dos semanas que dejé de fumar, y aunque a...
# 4  He estado pensando en dejar de fumar, pero es ...
#
#                                  clinician_utterance behavior_code_1
# 0  ¿Qué técnicas de respiración has encontrado má...              OQ
# 1  ¿Has notado que has tenido menos conflictos co...              CQ
# 2  ¿Cómo has manejado las ganas de fumar desde qu...              OQ
# 3  ¿Has tenido algún momento en el que hayas sent...              CQ
# 4  ¿Qué estrategias has usado antes para manejar ...              OQ

# %%
df_quest.shape
# Out:
# (200, 3)

# %%
df_quest['behavior_code_1'].value_counts()
# Out:
# behavior_code_1
# OQ    100
# CQ    100
# Name: count, dtype: int64

# %% [markdown]
# ## Reflex dataframe:

# %%
df_reflex.head()
# Out:
#                                     client_utterance  \
# 0  He empezado a seguir una rutina de sueño más r...
# 1  No puedo cumplir con las visitas de mi supervi...
# 2  He estado cumpliendo con todas las citas de mi...
# 3  No necesito seguir un horario para dormir, est...
# 4  No hago nada más que sentarme en casa todo el ...
#
#                                  clinician_utterance behavior_code_1
# 0  Parece que estás encontrando el coraje para pr...              CR
# 1  No puedes cumplir con las visitas de tu superv...              SR
# 2  Entiendo que has cumplido con todas las citas ...              SR
# 3  Estás siendo defensivo para evitar reconocer q...              CR
# 4  Sientes que no haces nada más que sentarte en ...              SR

# %%
df_reflex['behavior_code_1'].value_counts()
# Out:
# behavior_code_1
# SR    102
# CR     98
# Name: count, dtype: int64

# %%
df_reflex.shape
# Out:
# (200, 3)
